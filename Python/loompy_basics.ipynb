# %% [markdown]
# - **Purpose:** Explore the loompy package
# - **Date:** September 10, 2025

# %% [markdown]
# # Step 1
# Setting it up

# %%
# Install the package
# !pip install -U loompy
# Out:
# Collecting loompy
#   Downloading loompy-3.0.8.tar.gz (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from loompy) (3.14.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from loompy) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from loompy) (1.16.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from loompy) (75.2.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from loompy) (0.60.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from loompy) (8.2.1)
# Collecting numpy-groupies (from loompy)
#   Downloading numpy_groupies-0.11.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->loompy) (0.43.0)
# Downloading numpy_groupies-0.11.3-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 2.3 MB/s eta 0:00:00
# Building wheels for collected packages: loompy
#   Building wheel for loompy (setup.py) ... done
#   Created wheel for loompy: filename=loompy-3.0.8-py3-none-any.whl size=54012 sha256=50188f26735059e0e80ee152bc131748628151d65b2759d1f558378e9c71d5a9
#   Stored in directory: /root/.cache/pip/wheels/2e/45/28/2c7afc7f9eab47612e1b5090cfb9ba0f00777625064039a6af
# Successfully built loompy
# Installing collected packages: numpy-groupies, loompy
# Successfully installed loompy-3.0.8 numpy-groupies-0.11.3

# %%
# Download loom file
# !wget http://loom.linnarssonlab.org/clone/Previously%20Published/Oligos.loom
# Out:
# --2025-09-10 09:28:01--  http://loom.linnarssonlab.org/clone/Previously%20Published/Oligos.loom
# Resolving loom.linnarssonlab.org (loom.linnarssonlab.org)... 104.197.181.233
# Connecting to loom.linnarssonlab.org (loom.linnarssonlab.org)|104.197.181.233|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18867689 (18M) [application/octet-stream]
# Saving to: ‘Oligos.loom’
#
# Oligos.loom         100%[===================>]  17.99M  93.0MB/s    in 0.2s
#
# 2025-09-10 09:28:01 (93.0 MB/s) - ‘Oligos.loom’ saved [18867689/18867689]

# %%
# Import packages
import loompy as lp
import numpy as np
import pandas as pd

# %%
# Read the loom file
oligo = lp.connect("Oligos.loom")
oligo
# Out:
# <p><strong>Oligodendrocytes</strong> 17063 rows, 3654 columns, 1 layer<br/>(showing up to 10x10)<br/>Oligos.loom<br/>name: <em>2017/12/25 21:43:39</em><br/>name: <em>Oligodendrocytes by Marques et al. 2016</em><br/>name: <em>doi:10.1126/science.aaf6463</em><br/>name: <em>20180405T232027.874872Z</em><br/>name: <em>Oligodendrocytes</em><br/>name: <em>http://science.sciencemag.org/content/352/6291/1326</em><br/><table><tr><td>&nbsp;</td><td><strong>cell_id</strong></td><td>C1-1771017-032-E11</td><td>C1-1862091-035-C04</td><td>C1-1771017-030-G04</td><td>C1-1772089-196-A01</td><td>C1-1862091-032-F04</td><td>C1-1771017-032-C02</td><td>C1-1772099-078-B10</td><td>C1-1772072-243-D07</td><td>C1-1862091-105-E12</td><td>C1-1772099-048-E04</td><td>...</td></tr><tr><td><strong>Gene</strong></td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>...</td></tr><tr><td>Xkr4</td><td>&nbsp;</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>0</td><td>...</td></tr><tr><td>Rp1</td><td>&nbsp;</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>...</td></tr><tr><td>Sox17</td><td>&nbsp;</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>...</td></tr><tr><td>Mrpl15</td><td>&nbsp;</td><td>0</td><td>1</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>0</td><td>...</td></tr><tr><td>Lypla1</td><td>&nbsp;</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>...</td></tr><tr><td>Rgs20</td><td>&nbsp;</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>...</td></tr><tr><td>Oprk1</td><td>&nbsp;</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>...</td></tr><tr><td>Npbwr1</td><td>&nbsp;</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>...</td></tr><tr><td>St18</td><td>&nbsp;</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>...</td></tr><tr><td>Sntg1</td><td>&nbsp;</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>1</td><td>...</td></tr><tr><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td></tr></table>

# %%
# Close the loom file
oligo.close()

# %%
# Filter by one of the genes
oligo[oligo.ra.Gene == "Olig2", :]
# Out:
# array([[0, 2, 6, ..., 0, 0, 0]])

# %% [markdown]
# # Step 2
# Understanding the semantics of loom files

# %% [markdown]
# ## 1. Connecting and saving
#
#
# *   Loom files are **not fully loaded into memory**, only the metadata is loaded
# *   Loom files are like **databases** that users can connect to
# *   When the work is done, the connection needs to be **closed**

# %% [markdown]
# ## 2. Reading and writing
#
#
# *   Reading and writing are not concurrently supported
# *   Not suitable for storing data

# %% [markdown]
# ## 3. Efficient indexing and compression
#
#
# *   The main matrix is stored in **chunked** format
# *   The chunks are automatically **compressed** and **decompressed**

# %% [markdown]
# # 4. Matrix and attributes
#
#
# *   2D matrix
# *   Columns can be added but not rows

# %% [markdown]
# ## 5. Data types
#
#
# *   The **main matrix** and any additional layers are 2D arrays of numbers which can be 8, 16, 32 or 64-bit signed or unsigned integer or 16, 32 or 64-bit floats
# *   **Attirbutes** are N-dimensional arrays. The size of the first dimension must match the corresponding matrix dimension

# %% [markdown]
# # Step 3
# Creating loom file from fastq file

# %%
# Download kallisto
# !wget https://github.com/pachterlab/kallisto/releases/download/v0.46.0/kallisto_linux-v0.46.0.tar.gz
# !tar -xf kallisto_linux-v0.46.0.tar.gz
# !cp kallisto/kallisto /usr/local/bin/
# Out:
# --2025-09-10 03:01:55--  https://github.com/pachterlab/kallisto/releases/download/v0.46.0/kallisto_linux-v0.46.0.tar.gz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/26562905/8cbbf280-8ca9-11e9-8c32-bec32f378e41?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-09-10T04%3A01%3A02Z&rscd=attachment%3B+filename%3Dkallisto_linux-v0.46.0.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-09-10T03%3A00%3A12Z&ske=2025-09-10T04%3A01%3A02Z&sks=b&skv=2018-11-09&sig=ObrZEYkQFLqOv1bh97BTF7Nttf4ZyajLgiCsFo5oiKY%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NzQ3MzU3OSwibmJmIjoxNzU3NDczMjc5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.G7eSeh8Iiv63MhDoZE7QfEG-D4S46p_b8_uHnOrKBbo&response-content-disposition=attachment%3B%20filename%3Dkallisto_linux-v0.46.0.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-09-10 03:01:55--  https://release-assets.githubusercontent.com/github-production-release-asset/26562905/8cbbf280-8ca9-11e9-8c32-bec32f378e41?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-09-10T04%3A01%3A02Z&rscd=attachment%3B+filename%3Dkallisto_linux-v0.46.0.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-09-10T03%3A00%3A12Z&ske=2025-09-10T04%3A01%3A02Z&sks=b&skv=2018-11-09&sig=ObrZEYkQFLqOv1bh97BTF7Nttf4ZyajLgiCsFo5oiKY%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NzQ3MzU3OSwibmJmIjoxNzU3NDczMjc5LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.G7eSeh8Iiv63MhDoZE7QfEG-D4S46p_b8_uHnOrKBbo&response-content-disposition=attachment%3B%20filename%3Dkallisto_linux-v0.46.0.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7260524 (6.9M) [application/octet-stream]
# Saving to: ‘kallisto_linux-v0.46.0.tar.gz.1’
#
# kallisto_linux-v0.4 100%[===================>]   6.92M  --.-KB/s    in 0.09s
#
# 2025-09-10 03:01:55 (72.9 MB/s) - ‘kallisto_linux-v0.46.0.tar.gz.1’ saved [7260524/7260524]

# %%
# Download bustools
# !wget https://github.com/BUStools/bustools/releases/download/v0.39.3/bustools_linux-v0.39.3.tar.gz
# !tar -xf bustools_linux-v0.39.3.tar.gz
# !cp bustools/bustools /usr/local/bin/
# Out:
# --2025-09-10 03:04:01--  https://github.com/BUStools/bustools/releases/download/v0.39.3/bustools_linux-v0.39.3.tar.gz
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/157250571/bf828d00-b3b4-11e9-801d-3356b95223ea?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-09-10T03%3A59%3A36Z&rscd=attachment%3B+filename%3Dbustools_linux-v0.39.3.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-09-10T02%3A59%3A22Z&ske=2025-09-10T03%3A59%3A36Z&sks=b&skv=2018-11-09&sig=sVe7aOGMx1B3ZbFb6quBCpkviSkuk%2FlCu1v6P2xj%2FcA%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NzQ3Mzc0MSwibmJmIjoxNzU3NDczNDQxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.CVnDJYa2WpHtVuDitAloEnjk3Qly5dQJLEJ-fGf0mS0&response-content-disposition=attachment%3B%20filename%3Dbustools_linux-v0.39.3.tar.gz&response-content-type=application%2Foctet-stream [following]
# --2025-09-10 03:04:01--  https://release-assets.githubusercontent.com/github-production-release-asset/157250571/bf828d00-b3b4-11e9-801d-3356b95223ea?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-09-10T03%3A59%3A36Z&rscd=attachment%3B+filename%3Dbustools_linux-v0.39.3.tar.gz&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-09-10T02%3A59%3A22Z&ske=2025-09-10T03%3A59%3A36Z&sks=b&skv=2018-11-09&sig=sVe7aOGMx1B3ZbFb6quBCpkviSkuk%2FlCu1v6P2xj%2FcA%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1NzQ3Mzc0MSwibmJmIjoxNzU3NDczNDQxLCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.CVnDJYa2WpHtVuDitAloEnjk3Qly5dQJLEJ-fGf0mS0&response-content-disposition=attachment%3B%20filename%3Dbustools_linux-v0.39.3.tar.gz&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 403317 (394K) [application/octet-stream]
# Saving to: ‘bustools_linux-v0.39.3.tar.gz’
#
# bustools_linux-v0.3 100%[===================>] 393.86K  --.-KB/s    in 0.04s
#
# 2025-09-10 03:04:01 (8.69 MB/s) - ‘bustools_linux-v0.39.3.tar.gz’ saved [403317/403317]

# %%
# Download pre-built index of human genome
# !wget https://storage.googleapis.com/linnarsson-lab-www-blobs/human_GRCh38_gencode.v31.tar.gz
# Out:
# --2025-09-10 02:25:55--  https://storage.googleapis.com/linnarsson-lab-www-blobs/human_GRCh38_gencode.v31.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 192.178.219.207, 108.177.12.207, 74.125.26.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|192.178.219.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5007735860 (4.7G) [application/x-tar]
# Saving to: ‘human_GRCh38_gencode.v31.tar.gz’
#
# human_GRCh38_gencod 100%[===================>]   4.66G   108MB/s    in 55s
#
# 2025-09-10 02:26:50 (86.8 MB/s) - ‘human_GRCh38_gencode.v31.tar.gz’ saved [5007735860/5007735860]

# %%
# Decompress the folder
# !tar -xf human_GRCh38_gencode.v31.tar.gz

# %%
# List the contents of the decompressed directory
# !ls -1 human_GRCh38_gencode.v31.600
# Out:
# 10xv1_whitelist.txt
# 10xv2_whitelist.txt
# 10xv3_whitelist.txt
# fragments2genes.txt
# gencode.v31.fragments.idx
# gencode.v31.metadata.tab
# manifest.json
# spliced_fragments.txt
# unspliced_fragments.txt

# %%
# Download metadata and fastq files
# !wget http://cf.10xgenomics.com/samples/cell-exp/3.0.0/pbmc_1k_v3/pbmc_1k_v3_fastqs.tar
# Out:
# --2025-09-10 02:34:08--  http://cf.10xgenomics.com/samples/cell-exp/3.0.0/pbmc_1k_v3/pbmc_1k_v3_fastqs.tar
# Resolving cf.10xgenomics.com (cf.10xgenomics.com)... 104.18.1.173, 104.18.0.173, 2606:4700::6812:ad, ...
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.1.173|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cf.10xgenomics.com/samples/cell-exp/3.0.0/pbmc_1k_v3/pbmc_1k_v3_fastqs.tar [following]
# --2025-09-10 02:34:08--  https://cf.10xgenomics.com/samples/cell-exp/3.0.0/pbmc_1k_v3/pbmc_1k_v3_fastqs.tar
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.1.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5549312000 (5.2G) [application/x-tar]
# Saving to: ‘pbmc_1k_v3_fastqs.tar’
#
# pbmc_1k_v3_fastqs.t 100%[===================>]   5.17G  21.5MB/s    in 4m 15s
#
# 2025-09-10 02:38:24 (20.7 MB/s) - ‘pbmc_1k_v3_fastqs.tar’ saved [5549312000/5549312000]

# %%
# Extract the files
# !tar -xvf pbmc_1k_v3_fastqs.tar
# Out:
# pbmc_1k_v3_fastqs/
# pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L001_R2_001.fastq.gz
# pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L002_I1_001.fastq.gz
# pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L001_R1_001.fastq.gz
# pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L002_R1_001.fastq.gz
# pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L002_R2_001.fastq.gz
# pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L001_I1_001.fastq.gz

# %%
# Create the loom file
# !loompy fromfq 1kPBMC.loom 1kPBMC human_GRCh38_gencode.v31.600 metadata.tab pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L001_R1_001.fastq.gz pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L001_R2_001.fastq.gz pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L002_R1_001.fastq.gz pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L002_R2_001.fastq.gz
# Out:
# Loompy v3.0.8 by Linnarsson Lab 🌸 (http://linnarssonlab.org & http://loompy.org)
#
# 2025-09-10 03:04:13,728 - INFO - Using 2 threads.
# 2025-09-10 03:04:13,729 - INFO - kallisto bus -i human_GRCh38_gencode.v31.600/gencode.v31.fragments.idx -o /tmp/tmp5hfmfo5d -x 10xv3 -t 2 pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L001_R1_001.fastq.gz pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L001_R2_001.fastq.gz pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L002_R1_001.fastq.gz pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L002_R2_001.fastq.gz
# 2025-09-10 03:04:13,781 - INFO - [index] k-mer length: 31
# 2025-09-10 03:04:13,781 - INFO - [index] number of targets: 845,338
# 2025-09-10 03:04:13,782 - INFO - [index] number of k-mers: 271,648,279
# Traceback (most recent call last):
#   File "/usr/local/bin/loompy", line 8, in <module>
#     sys.exit(cli())
#              ^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1442, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1363, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1830, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1226, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 794, in invoke
#     return callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/loompy/commands.py", line 34, in fromfq
#     create_from_fastq(loomfile, sampleid, list(fastqs), indexdir, metadatafile, threads)
#   File "/usr/local/lib/python3.12/dist-packages/loompy/bus_file.py", line 418, in create_from_fastq
#     for line in execute(cmd, synchronous):
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/loompy/bus_file.py", line 365, in execute
#     raise subprocess.CalledProcessError(return_code, cmd)
# subprocess.CalledProcessError: Command '['kallisto', 'bus', '-i', 'human_GRCh38_gencode.v31.600/gencode.v31.fragments.idx', '-o', '/tmp/tmp5hfmfo5d', '-x', '10xv3', '-t', '2', 'pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L001_R1_001.fastq.gz', 'pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L001_R2_001.fastq.gz', 'pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L002_R1_001.fastq.gz', 'pbmc_1k_v3_fastqs/pbmc_1k_v3_S1_L002_R2_001.fastq.gz']' died with <Signals.SIGKILL: 9>.

# %% [markdown]
# **Comment:** Encountered out of memory error

# %% [markdown]
# # Step 4
# API walkthrough

# %%
# Creating loom file
## The following inputs are required
#1. A main matrix --> numpy dense array or scipy sparse array
#2. Two dictionaries containing the attributes for the row and the column
filename = "test_file.loom"
main_mat = np.arange(10000).reshape(100, 100)
row_att = {"RowAttr": ["row" + str(num) for num in list(range(1, 101))]}
col_att = {"ColAttr": ["col" + str(num) for num in list(range(1, 101))]}
lp.create(filename, main_mat, row_attrs=row_att, col_attrs=col_att)

# %%
# Connecting to loompy file
lp_file = lp.connect("test_file.loom")
lp_file
# Out:
# <p>100 rows, 100 columns, 1 layer<br/>(showing up to 10x10)<br/>test_file.loom<br/>name: <em>20250910T084626.040650Z</em><br/>name: <em>3.0.0</em><br/><table><tr><td>&nbsp;</td><td><strong>ColAttr</strong></td><td>col1</td><td>col2</td><td>col3</td><td>col4</td><td>col5</td><td>col6</td><td>col7</td><td>col8</td><td>col9</td><td>col10</td><td>...</td></tr><tr><td><strong>RowAttr</strong></td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>...</td></tr><tr><td>row1</td><td>&nbsp;</td><td>0</td><td>1</td><td>2</td><td>3</td><td>4</td><td>5</td><td>6</td><td>7</td><td>8</td><td>9</td><td>...</td></tr><tr><td>row2</td><td>&nbsp;</td><td>100</td><td>101</td><td>102</td><td>103</td><td>104</td><td>105</td><td>106</td><td>107</td><td>108</td><td>109</td><td>...</td></tr><tr><td>row3</td><td>&nbsp;</td><td>200</td><td>201</td><td>202</td><td>203</td><td>204</td><td>205</td><td>206</td><td>207</td><td>208</td><td>209</td><td>...</td></tr><tr><td>row4</td><td>&nbsp;</td><td>300</td><td>301</td><td>302</td><td>303</td><td>304</td><td>305</td><td>306</td><td>307</td><td>308</td><td>309</td><td>...</td></tr><tr><td>row5</td><td>&nbsp;</td><td>400</td><td>401</td><td>402</td><td>403</td><td>404</td><td>405</td><td>406</td><td>407</td><td>408</td><td>409</td><td>...</td></tr><tr><td>row6</td><td>&nbsp;</td><td>500</td><td>501</td><td>502</td><td>503</td><td>504</td><td>505</td><td>506</td><td>507</td><td>508</td><td>509</td><td>...</td></tr><tr><td>row7</td><td>&nbsp;</td><td>600</td><td>601</td><td>602</td><td>603</td><td>604</td><td>605</td><td>606</td><td>607</td><td>608</td><td>609</td><td>...</td></tr><tr><td>row8</td><td>&nbsp;</td><td>700</td><td>701</td><td>702</td><td>703</td><td>704</td><td>705</td><td>706</td><td>707</td><td>708</td><td>709</td><td>...</td></tr><tr><td>row9</td><td>&nbsp;</td><td>800</td><td>801</td><td>802</td><td>803</td><td>804</td><td>805</td><td>806</td><td>807</td><td>808</td><td>809</td><td>...</td></tr><tr><td>row10</td><td>&nbsp;</td><td>900</td><td>901</td><td>902</td><td>903</td><td>904</td><td>905</td><td>906</td><td>907</td><td>908</td><td>909</td><td>...</td></tr><tr><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td><td>...</td></tr></table>

# %%
# Shape of the object
lp_file.shape
# Out:
# (100, 100)

# %%
# Global attribute keys
with lp.connect("Oligos.loom") as ds:
  print(ds.attrs.keys())
# Out:
# ['CreationDate', 'description', 'doi', 'last_modified', 'title', 'url']

# %%
# Title of the attributes
with lp.connect("Oligos.loom") as ds:
  ds.attrs.title = "Oligos"
  print(ds.attrs.title)
# Out:
# Oligos

# %%
# Row attributes
with lp.connect("Oligos.loom") as ds:
  print(ds.ra.keys())
# Out:
# ['Gene']

# %%
# Column attribute
with lp.connect("Oligos.loom") as ds:
  print(ds.ca.keys())
# Out:
# ['cell_id']

# %%
# Look at the layers
with lp.connect("Oligos.loom") as ds:
  print(ds.layers.keys())
# Out:
# ['']

# %%
# Graphs
with lp.connect("Oligos.loom") as ds:
  print(ds.row_graphs.keys())
  print(ds.col_graphs.keys())
# Out:
# []
# []

# %%
# The scan method enables scanning an axis of the loom file and retrieve information

# %%
# Pacakge versions
print("numpy version: ", np.__version__)
print("pandas version: ", pd.__version__)
print("loompy version: ", lp.__version__)
# Out:
# numpy version:  2.0.2
# pandas version:  2.2.2
# loompy version:  3.0.8
